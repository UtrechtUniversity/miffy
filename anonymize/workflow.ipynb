# %% [markdown]
# # Workflow:  Replace usernames with pseudo data

# %% [markdown]
# ### Steps ###
# 0. **Formulate Goal**
# 1. **Determine which variable should be selected to reach goal**
# 2. **Select raw data source**
# 3. **List available information in raw data source**
# 4. **Create dictionary with usernames and substitutes**
# 5. **Create function to search for sensitive info and replace it with pseudo data**
# ____________________________________________________________________________________________________________

# %%
import json
import pandas as pd
from pathlib import Path
import numpy as np
import emojis
import emoji
import regex
import matplotlib.pyplot as plt
from datetime import date
import re

# %% [markdown]
# ### 0. Goal
#
# **Develop generic label search function for sensitive info in (instagram) .json**

# %% [markdown]
# ### 1. Variable
#
# * Automatically find all usernames in all .json files
# * Automatically create a dictionary with usernames as original key and (pseudo) anonymized username as substitute
# * Automatically change sensitive user information to (pseudo) anonymized key

# %% [markdown]
# ### 2. Raw data source
#
# **Instagram**
#
# Instagram download contains the following folders:
#
# * direct  > date folders (YYDDMM) > photos directly send to other users via 'message' on that day
# * photos  > date folders (YYDDMM) > photos posted on your 'page' that day
# * videos  > date folders (YYDDMM) > videos posted on your 'page' that day
# * stories > date folders (YYDDMM) > photos posted on your 'story' that day
# * profile > date folders (YYDDMM) > photo used as profile picture on that day
#
# Instagram download contains the following files (not in folders):
# 0. **information_about_you**: your primary location (home adress)
# 1. **searches**: your search info on instagram with corresponding timestamp
# 2. **autofill**: ? (*'You have no data in this section'*)
# 3. **checkout**: the email of payment account (N.B. insta if free)
# 4. **connections**: all your connections with corresponding timestamps (e.g., when did you start following them or vice versa)
# 5. **devices**: information about the used devices
# 6. **likes**: likes of media posts and comments of other users with corresponding timestamp
# 7. **media**: caption of photo posts, video posts, and stories with corresponding timestamp and path to corresponding media (within download)
# 8. **seen_content**: all content (posts, videos, adds, chains) you've seen on instagram with corresponding timestamp and author (username of poster)
# 9. **settings**: account setting (allow comments from)
# 10. **stories_activities**: your activity on story polls of other users
# 11. **account_history**: info of logged in devices (e.g., ip adress) and registration info (e.g., name, email)
# 12. **comments**: your comments on other (unknown) users posts with corresponding timestamp
# 13. **messages**: private messages between you and other users with corresponding timestamps, shared media, links, etc.
# 14. **profile**: all information about your profile (e.g., username, email, full name, start date, etc.)
# 15. **saved**: all saved media with corresponding timestamp and owner of media (username)
# 16. **uploaded_contacts**: ? (*'You have no data in this section'*)

# %% [markdown]
# ### 3. List available information

# %% [markdown]
# #### What sensitive info is where?
#
# Files containing 'usernames'
# * 1. searches.json --> username of other users (direct)
# * 4. connections.json --> username of other users (direct) (your connections: people following you, or people you follow)
# * 6. likes.json --> username of other users (direct)
# * 7. media.json --> username of other users (indirect) (within your caption you can tagg people with @username)
# * 8. seen_content.json --> username of other (unknown) users (direct)
# * 10. stories_activities.json --> username of other users (direct)
# * 11. account_history.json --> registration_info list
# * 12. comments.json --> username of other (unkown) users (direct + indirect) (within your comment you can tagg people with @username)
# * 13. messages.json --> username of other users (direct + indirect) (within your caption you can tagg people with @username, but the full names of the users are also used frequently 'hey Kees! how are you?')
# * 14. profile.json --> username of your account (direct)
# * 15. saved.json --> username of other users (direct)
#
# Files containing other personal info
# * 0. information_about_you.json --> primary location (home adress)
# * 3. checkout.json --> payment_account_emails
# * 5. devices.json --> device_id
# * 11. account_history.json --> login_history (e.g., ip adress, device id) and registration_info (e.g., name, email)
# * 14. profile.json --> all profile info (e.g., email, gender, name, link to profile picture, username, etc.)

# %% [markdown]
# ### 4. Create dictionary with usernames and substitutes

# %% [markdown]
# #### Download data from instagram
# * Go to your profile and click on the wheel.
# * Click Privacy and Security.
# * Scroll down to Data Download and click Request Download.
# * Enter the email address where you'd like to receive a link to your data and click Next.
# * Enter your Instagram account password and click Request Download.
# * You'll soon receive an email titled Your Instagram Data with a link to your data. Click Download Data and follow the instructions to finish downloading your information
#
# #### Enter relevant information
# In said email, Instagram provides your data in a zip folder with the following title: 'username_currentdate'. Save this zipped folder in your *Downloads* folder. N.B. Make sure to save this workflow script in the same folder as the data!
#
# To correctly access your instagram data, please fill in your username and name (the latter is for accessing your computer path correctly: e.g., C:/Users/*name*/Downloads).

# %%
username = 'roosvoor' # Enter username here
name = 'Roos' # Enter name of computer here

# If you downloaded the data today
datum = f'{date.today()}'
datum = re.findall(r'\d+', datum)
datum = ''.join(datum)

# If you downloaded the data on another date
# datum = '' # Enter date in format YYYYMMDD

# %% [markdown]
# #### Read files

# %%
# Set path to zip folder
folder = username+'_'+datum+'.zip'
project = Path('C:/Users/'+name+'/Downloads')
data = project / folder
data
# Out:
# WindowsPath('C:/Users/Roos/Downloads/roosvoor_20200605.zip')

# %%
# importing required modules 
from zipfile import ZipFile 
  
# specifying the zip file name 
file_name = data
  
# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# information_about_you.json                     2020-06-05 01:55:22           61
# devices.json                                   2020-06-05 01:55:22         1429
# settings.json                                  2020-06-05 01:55:22           35
# seen_content.json                              2020-06-05 01:55:22        61362
# stories_activities.json                        2020-06-05 01:55:22           53
# connections.json                               2020-06-05 01:55:22        25268
# saved.json                                     2020-06-05 01:55:22        13165
# searches.json                                  2020-06-05 01:55:22         2492
# messages.json                                  2020-06-05 01:55:22       347382
# profile.json                                   2020-06-05 01:55:22          415
# media.json                                     2020-06-05 01:55:22        53862
# likes.json                                     2020-06-05 01:55:22        67293
# guides.json                                    2020-06-05 01:55:22           36
# uploaded_contacts.json                         2020-06-05 01:55:22           36
# comments.json                                  2020-06-05 01:55:22         2670
# checkout.json                                  2020-06-05 01:55:22           48
# autofill.json                                  2020-06-05 01:55:22           36
# account_history.json                           2020-06-05 01:55:22         5209
# photos/202006/4bb09e9680a89a1dbc6b4b307a86d11a.jpg 2020-06-05 01:55:22         3360
# photos/202005/8b08f4d4838ecaf566326f6cdaca7e37.jpg 2020-06-05 01:55:22        66085
# photos/202003/2075921aba6fb776c498512841a02bbf.jpg 2020-06-05 01:55:22       110111
# photos/202003/9af411fcc7be8bb8694554a57ddf71ae.jpg 2020-06-05 01:55:22        41879
# direct/201906/8478a555bc8e2e0d5fa1b5d9d8eef490.jpg 2020-06-05 01:55:22        16748
# direct/201906/2024591b25e3c5151721638bdca5b9b4.jpg 2020-06-05 01:55:22        19540
# direct/201906/b60d22b1f8fb78bf75beb60d55104a02.jpg 2020-06-05 01:55:22       190032
# direct/201910/dd192389abb786922b817fd8374da9f9.jpg 2020-06-05 01:55:22       116569
# direct/201907/49ea8f24e27204b11fee1df497f7493b.jpg 2020-06-05 01:55:22       138548
# direct/201805/956952e80634239851968a588df6c12c.jpg 2020-06-05 01:55:22        58223
# direct/202005/80a7b9064f080e53f7e9aa932d6316b2.jpg 2020-06-05 01:55:22       100069
# direct/201902/bbd4527f08a67c2fdcd7a16cc5ca1738.jpg 2020-06-05 01:55:22        47269
# direct/201909/85b843f2e6af199e90166ebf600a2caf.jpg 2020-06-05 01:55:22       123528
# Extracting all the files now...
# Done!

# %%
# Passive files (generated by insta)
json_file_you = project / 'information_about_you.json'
json_file_autofill = project / 'autofill.json'
json_file_pay = project / 'checkout.json'
json_file_users = project / 'connections.json'
json_file_device = project / 'devices.json'
json_file_settings = project / 'settings.json'
json_file_account = project / 'account_history.json'
json_file_user = project / 'profile.json'
json_file_contact = project / 'uploaded_contacts'

# Interaction files (generated by users)
json_file_like = project / 'likes.json'
json_file_med = project / 'media.json'
json_file_seen = project / 'seen_content.json'
json_file_stories = project / 'stories_activities.json'
json_file_com = project / 'comments.json'
json_file_mes = project / 'messages.json'
json_file_saved = project / 'saved.json'
json_file_search = project / 'searches.json'

# %% [markdown]
# #### Find all 'explicit' usernames

# %%
def usernames():
    
    # Load profile.json to get username of user
    with open(json_file_user, encoding = "utf8") as json_user:
        user = json.load(json_user)
    
    user = pd.DataFrame.from_dict(user, 
        orient = 'index').T 
    
    # Load connections.json to get username of all connections
    with open(json_file_users, encoding = "utf8") as json_users:
        users = json.load(json_users)

    users = pd.DataFrame.from_dict(users, 
        orient = 'index').T 

    users = users.index.values.tolist()
    
    # Create scramble function
    from random import shuffle

    def shuffle_word(word):
        word = list(word)
        shuffle(word)
        return ''.join(word)

    # Create dictionary with original username as key
    dictionary = {}
    dictionary = {user['username'][0]: ('__'+shuffle_word(user['username'][0]))}
    
    for name in users:
        new = {name: ('__'+shuffle_word(name))}
        dictionary.update(new)
    
    # look for usernames outside of connections 
    # Saved media
    with open(json_file_saved, encoding = "utf8") as json_saved:
        saved = json.load(json_saved)
    
    users = pd.DataFrame(saved['saved_media'])[1]
    
    # Likes
    with open(json_file_like, encoding = "utf8") as json_likes:
        likes = json.load(json_likes)
    
    user_like = pd.DataFrame(likes['media_likes'])[1]
    user_like = user_like.append(pd.DataFrame(likes['comment_likes'])[1])
        
    # Seen content
    with open(json_file_seen, encoding = "utf8") as json_seen:
        seen = json.load(json_seen)
    
    user_seen = pd.DataFrame(seen['chaining_seen'])['username']
    user_seen = user_seen.append(pd.DataFrame(seen['ads_seen'])['author'])
    user_seen = user_seen.append(pd.DataFrame(seen['posts_seen'])['author'])
    user_seen = user_seen.append(pd.DataFrame(seen['videos_watched'])['author'])
    
    # Search media
    with open(json_file_search, encoding = "utf8") as json_search:
        search = json.load(json_search)

    user_search = pd.DataFrame(search)['search_click']
    
    # Media comments
    with open(json_file_com, encoding = "utf8") as json_comments:
        comments = json.load(json_comments)

    user_com = pd.DataFrame(comments['media_comments'])[2]
    
    # Merge all usernames
    users = users.append(user_seen)
    users = users.append(user_like)
    users = users.append(user_search)
    users = users.append(user_com)
    users = set(users)
    
    for name in users:
        if name in dictionary:
            next
        else: 
            dictionary.update({name:('__'+shuffle_word(name))})
    
    return(dictionary)

# %%
usernames = usernames()
usernames
# Out:
# {'roosvoor': '__ovrsrooo',
#  'beberson': '__obrbnsee',
#  'danielpolosetzky': '__oolptadlnyiezesk',
#  'sophie_soof': '__ohiso_ofspe',
#  'symonab': '__asmonyb',
#  'mana.fazel': '__.leazaamnf',
#  'evaendema': '__deaemnaev',
#  'zack_from_earth': '__hearrao_fmz_ktc',
#  'jboonstra73': '__artoj37obns',
#  '_romyrachel': '__ahlmr_ycore',
#  'lauraderooij': '__odeaiurjrloa',
#  'veerlegewoon': '__oeweelnrgevo',
#  'sophiejacobs1993': '__139ieocp9jhsobsa',
#  'momo_schaap': '__paohomcams_',
#  'mitalipoovs': '__tiiapvsmolo',
#  'bonnievanderlee': '__bennlieaoeerndv',
#  'agnesdesl': '__edessangl',
#  'theycallmenita': '__hymealttcinlea',
#  'die_ene_insta': '__dstani_n_ieee',
#  'hannadohle': '__naheaholnd',
#  'jurrekuin': '__jikreurnu',
#  'yaramiora': '__ayoramria',
#  'faraah.aulia': '__laarahua.aif',
#  'bluunie': '__enuiubl',
#  'tiarmaguvnor': '__umirorgatanv',
#  'ingevanooijen': '__ennoivijnoega',
#  'dieuweertje': '__ujterieedew',
#  'al.bert.0': '__.a0t.brle',
#  'annelotte2': '__enetotnla2',
#  'hugomcgurran': '__gharoucmgrun',
#  'anouckdh': '__ahnuockd',
#  'mitmettoni': '__ntetmotiim',
#  'ellinaa': '__neallia',
#  'floor___': '__oo_l_fr_',
#  'louisebc': '__bluioecs',
#  'laurameershoek': '__alohsaekreuerm',
#  'kimvuurboom': '__romkubiomuv',
#  'dieffiee': '__ieeiefdf',
#  'vera.anne.bakker': '__eanenkvr..eaarbk',
#  'tamarabreugelmans': '__aeatnsgruarmelbma',
#  'hannahvanderstok': '__dnraaksehvanhnot',
#  'tesselbossen': '__teessseolsbn',
#  'robinvanschuylenburch': '__rnyoncehnrvhscabibulu',
#  'rafickdemol': '__irlkdmeaofc',
#  'sboogje': '__sebogjo',
#  'rrougoor': '__orurrgoo',
#  'silviabrouwer': '__uvirlabwiorse',
#  'luuk_pier': '__eku_lpuir',
#  'mbruinsma': '__msmurniab',
#  'chairaserrarens': '__earacarrhressni',
#  'juulhuitema': '__utijuumealh',
#  'evatullemans': '__alsnuaevtmel',
#  'charlottegredal': '__arrlatoeecthdlg',
#  'paula_i.m': '__i_.mpulaa',
#  'petraormel': '__melrtaepro',
#  'rebecca.gsm': '__agmc.ceserb',
#  'lizzie_jmo': '___eomliijzz',
#  'daphnee.ch': '__eh.nhpaedc',
#  'serinakragt': '__anrgekatsir',
#  'lissmits_': '__ts_ssmlii',
#  'farliaa': '__faaiarl',
#  'beertjelohman': '__hmbrjoatneeel',
#  'yaylailksoy': '__okylslayayi',
#  'pirosssvl': '__psvosrlis',
#  'guusje002': '__sg2ju0u0e',
#  'adjoayo': '__oaaoydj',
#  'htullemans': '__nsemllahtu',
#  'saarhollander': '__lrlarshaeonad',
#  'leonmarijn.s': '__rjmnoen.asli',
#  'marinbaelde': '__namaleebdir',
#  'appelpartje': '__aeltprepjap',
#  'doris.daily': '__dlioyr.dasi',
#  'zzzitaboeren': '__zitbzoznreea',
#  'ashleyhagers': '__easysahlgreh',
#  'terencespeyer': '__pnyreeecreets',
#  'sophieloveminoes': '__oehivslipmseoone',
#  'frederiquedanielle': '__iledreqeeflnaeuidr',
#  'florasana_': '___rlaofsana',
#  'winonavisuals': '__nwaiuvnslosia',
#  'lisadielessen': '__sdielelesisan',
#  'aniekdebruijn': '__ienbdrnajuike',
#  'kimnetsanav94': '__n9vemani4skta',
#  'rik.swart': '__satr.iwrk',
#  'photogravic___': '__vcg_pr_htaoi_o',
#  'elkedageenkater': '__eredneagaekklte',
#  'greenroutine_challenge': '__enoehlrelr_netgucniaeg',
#  'mischabenjamin': '__jnichmaesambni',
#  'bonbonlon': '__onnboolbn',
#  'marrisch16': '__s1c6amihrr',
#  'prast_bojo': '__aobrpsjot_',
#  'jutkayik': '__takiuykj',
#  'mandyxv': '__dnxvamy',
#  'teslaminor': '__oatlesirnm',
#  'xroozxx': '__oxrxozx',
#  'daaneus': '__anadues',
#  'nickmoerss': '__scriokmens',
#  'keskinarikan': '__akkkiesnnrai',
#  'stephanienaomi_': '__penhiae_sinmato',
#  'cafeblek': '__aefeblck',
#  'ann.eliess': '__nlee.snsai',
#  'rosenasrawi': '__araonerswis',
#  'mtdeklerk': '__lrektdmke',
#  'socialcognito': '__ioglosoticcan',
#  'konemonu': '__unkomone',
#  'anneliekeeeee': '__eaneieeenekel',
#  'constantaxel': '__teoncaastxnl',
#  'joycexv': '__oyjcexv',
#  'iva.with.an.i': '__.anivtiwai..h',
#  'meliscetincelik': '__ciclmeisieltnek',
#  'karlijn.kooij': '__ji.jrlioaoknk',
#  'alexander.janssen': '__ej.eexdanasslnarn',
#  'ieraa7': '__rai7ea',
#  'panas6': '__snap6a',
#  'samsalasamba': '__amabalasamss',
#  'kalkkunanakki': '__kkuaiaknakkln',
#  'serena_cam78': '__rmea_ea7c8sn',
#  'eline.l': '__.eilnle',
#  'evelien_dej': '__eljvedni_ee',
#  'milovb': '__boilvm',
#  'de.jan': '__djaen.',
#  'martijnvanderstraeten': '__trstvieeaartrmnannjed',
#  'kmdennard': '__erdmdnkna',
#  'aronvanbaarsen': '__oraabanrnsavne',
#  'lydiwo': '__oywdli',
#  'mariana_dq': '___aamndraiq',
#  'reiserida': '__eisriaedr',
#  'yoncabasa': '__canaaobys',
#  'laraborst': '__laarorbst',
#  'vandevussevanrijn': '__nsndneeivsaujvarv',
#  'gijoro': '__ogojri',
#  'annexevita': '__xinveatnea',
#  'jasmijnreemer': '__aermjemjnesri',
#  'suzannedezwaan': '__zanaewsnneazud',
#  'charlottehofstee': '__oerehctoestftlah',
#  'femkepaauwe': '__ewkemafpaeu',
#  'millardsamantha': '__dnaihlratmmsala',
#  'rik_a_s_brouwer': '__sew_ra_uk_ribro',
#  'catovan': '__cnvtaao',
#  'jolivere': '__loejrevi',
#  'tesshuigsloot': '__elsusotigosht',
#  'dkustebay': '__sabteyudk',
#  'cchderek': '__dccekehr',
#  'margotmett': '__rtoeammtgt',
#  'sanderjdw': '__wndsrjeda',
#  'mariasiermann': '__aanmraismenri',
#  'ribbitwebbo': '__orwbiibtebb',
#  'lovely.lisl': '__lllysli.ove',
#  'thijsjuan': '__ijtnjhaus',
#  'sophieabrahamse': '__aoshisbaehperma',
#  'stevenvoges': '__sgevseveont',
#  'jasmijnwassing': '__jnswasmisajngi',
#  'jeroen.138': '__o.e8jenr31',
#  'dorinewd': '__rdoweind',
#  'niekschuitemaker': '__ikrsmtnkeaiueehc',
#  'margoootjeee': '__gojtamoreeeo',
#  'mariannedhk': '__dnranamehik',
#  'joehughesjohnson': '__esjjhhhooogunsne',
#  'irispleijsier': '__iiijissrelerp',
#  'mikevzwieten': '__wkzvieitneme',
#  'ferial_ebm': '___alebermif',
#  'freyja_aich': '__aihfja_yerc',
#  'roh_ree': '__oerer_h',
#  'nesxxnes': '__exssxnne',
#  'emiliavsc': '__emlvicias',
#  'bodaartje': '__roebatdja',
#  'ritchie_terrence': '__eccr_hitenerreit',
#  'femkers': '__emesrkf',
#  'yinanni': '__aynniin',
#  'travelousdreamer': '__rtdsaaeloervurme',
#  'guidotm': '__omidtgu',
#  'goktugkilic': '__ogukcilkgti',
#  'tom_bekkers': '__bkerme_ksot',
#  'rrwijnker': '__nrwerrikj',
#  'evelieneongenae': '__enengnleeeiaeov',
#  'rubykeijzer': '__errukeibyzj',
#  'nikkibrands': '__nbskakiidrn',
#  'marijnevb': '__vnamrijbe',
#  'vic.bodiut': '__duiovc.tbi',
#  'smalartlisa': '__atlaasisrlm',
#  'jaspervdzwaag': '__wjdsaazrgvpae',
#  'odettebonnema': '__beetoentndmao',
#  'goosrobin': '__rsnogoiob',
#  'monjeezy': '__ezyneomj',
#  'bdeferrante': '__nrarftbedee',
#  'thaizezwart': '__itarazztwhe',
#  'sabineklinkhamer': '__inmbaliskerhenka',
#  'ivydijkstra': '__iksyaidvjtr',
#  'chrisannerog': '__einansorchrg',
#  'danaesme': '__nemaased',
#  'annabanana506': '__6naa5anaanbn0',
#  'samw_p': '__apw_ms',
#  'catsable': '__aaslcebt',
#  'laurensvangurpdesign': '__egesrnaanunvpiugdsrl',
#  'taalvoutjes': '__sulejvttoaa',
#  'cognito_uva': '__uoaogcintv_',
#  'talents.of.tno': '__fetsotl.nanot.',
#  'thearchbish0pofbanterbury': '__teboh0aucepfahyrthbirnbsr',
#  'hetparool': '__rtaoehopl',
#  'nos': '__nso',
#  'justtattoosz': '__sztotttuojas',
#  'littletattoosz': '__tttaotoitslelz',
#  'manbijthondnl': '__nhtnnjilodmba',
#  'trust_me_i_am_biologist': '____igtmituai_essoro_mbtl',
#  'chinupdarling.co': '__nagii.chpnludcro',
#  'vjeze_fur': '__ruzvfee_j',
#  'faberyayo': '__rfbayaeyo',
#  'gruntenveggieoats': '__gtogtesgeeuianvrn',
#  'dumpert': '__ptemdur',
#  'in_dutch_we_dont_say': '__oyt___ued_icnnwatshd',
#  'scienceparkmemes': '__eimcsepanesrekcm',
#  'eenvoud_': '___ovueend',
#  'theellenshow': '__helwhlsnoete',
#  'vancityreynolds': '__verdtyilnnaosyc',
#  'laekkerby': '__ykelkreba',
#  'dutchess_lazy': '__u_slheacstdyz',
#  'piecesofmindnl': '__ocmplsdneifnei',
#  'daan_kins': '__dkna_ains',
#  'zoee_mer': '__ome_reez',
#  'theschooloflife.amsterdam': '__toselmda.hrtseielchoomfaf',
#  'ozzymanreviews': '__aozrwnemisyevz',
#  'merazonia_refuge': '___rireaefaomzengu',
#  'boysinthewest69': '__oetwh9t6besnysi',
#  'nousveerman': '__uvnrsemnaoe',
#  'jorisjwbuis': '__soiirjwubsj',
#  'jessrome13': '__1sjees3rom',
#  'neuroseps': '__euprsneos',
#  'scottyish': '__itysohsct',
#  '_ssimon_': '___s_mosni',
#  'jorvisje': '__jirjeovs',
#  'thuisaandeamstel': '__talhsienasadmute',
#  'liekebeemster': '__ebsliemekrtee',
#  'ricodisco12': '__1diccroo2si',
#  'tizianahey': '__nzeatyihia',
#  'beautiful_minds': '__u_fnbltesidmaui',
#  'one.line.drawings': '__legaonne.r.swdnii',
#  'florent_leclercq.art': '__clllrt_.qtenarceefor',
#  'some_naked_bodies': '__mnseo_ded_abokesi',
#  'ted': '__tde',
#  'vintage_en_retro': '__tegtnone_arri_ev',
#  'asva_studentenunie': '__edneiveaus_nntauts',
#  'tovervrouwtje': '__tuoerrtwevvoj',
#  'carlosplatierluna': '__rtsrauoplcleanila',
#  'groosink': '__skroiong',
#  'ninismili': '__niiislinm',
#  'joanderuijter': '__uerrtjjenoida',
#  'shellysterk': '__krseetllysh',
#  'imkewieffer': '__eefiwimfekr',
#  'minnekoole': '__lkimnneeoo',
#  'serrarenschaira': '__arasncerrrsieha',
#  'puckmia': '__ucimpka',
#  'winonaolympia': '__plooiiynamwna',
#  'zack.koster': '__ck.etksozar',
#  'physics.ig': '__ygshci.pis',
#  'natgeo': '__neoatg',
#  'nosstories': '__toissosner',
#  'sarcasm_only': '__ynlcms_aaors',
#  'czweerus': '__seewzurc',
#  'albanvoppel': '__oanppalbvel',
#  'creaamsterdam': '__acstmareradme',
#  'little.tattoos': '__ltasottei.totl',
#  'lilmighty94': '__iyi4mgllht9',
#  'casperzweerus': '__eausewrcespzr',
#  'jana_ida_': '__adn__ijaa',
#  'rorymcsheffrey': '__orrscrfyhfymee',
#  'genahaensel': '__lesahenaneg',
#  'serrie_b': '__iserbe_r',
#  'crunchyzoah': '__cuohanchrzy',
#  'noenbrouwer': '__wnbrueroeno',
#  'juliavanvuuren': '__ajvuenlavriuun',
#  'hoiamber': '__eraomhib',
#  'liefsaiah': '__aaliiehfs',
#  'nas_ioui': '__ionuasi_',
#  'missmontreal_': '__amretossnl_mi',
#  'noracelineramakers': '__eanrkoremreiasclna',
#  'jeske_janssen': '__ejknnjesaess_',
#  'frank3fm': '__mnkfa3fr',
#  'jochemmyjer': '__ojjehcymerm',
#  'dwddtv': '__ddvdwt',
#  'kakhiel': '__ieakklh',
#  'de_speld': '__sdedl_ep',
#  'arjenlubach': '__ahjcbleruan',
#  'streetlabtv': '__vetealsttbr',
#  'debroervanroos': '__everooobdasrnr',
#  'jan_versteegh': '__ehjeetvsag_nr',
#  'leavecaricealone': '__eeaeorilacvencla',
#  'mitchellpeloso': '__llomoicsptlhee',
#  'geraldine_kemper': '__mrenlrp_eagkedei',
#  'at5.nl': '__a5tln.',
#  'sarahhyland': '__hnlsaaahydr',
#  'irisgombert': '__oegtirbsmir',
#  'emmawatson': '__mmetaosnwa',
#  'emilia_clarke': '__arcaikeelm_li',
#  'sophiet': '__pseihto',
#  'maisie_williams': '__lmalws_eisiimia',
#  'colesprouse': '__oorpeculsse',
#  'vandervoortkarlijn': '__revltrardajkinnoov',
#  'marijkevhilst': '__jhretlkimivsa',
#  'tanakamax': '__mnkaaaatx',
#  'drawinggpencil': '__radngwgiilpnce',
#  'drawings': '__rnwgsdai',
#  'sammyheutz21': '__s2mtzehym1ua',
#  'yazzzzo': '__yzzzaoz',
#  '9gag': '__9agg',
#  'mooswilhelm': '__ollwemimhso',
#  'gunesxo': '__uexngso',
#  'hannahtullemans': '__manlahuthnnleas',
#  'diedeleeuw': '__weeiduleed',
#  'elzinga.studio': '__euogzdia.tnsil',
#  'blokkkie': '__ebkkilko',
#  'bobbyoudshoorn': '__sounbobrobdoyh',
#  'tobiasspecker': '__otpcressaibke',
#  'art': '__rat',
#  'desiree.weijs': '__ieejdserw.esi',
#  'harmenabenga': '__ghnareenamba',
#  'gymgirlcrew': '__cmylrewiggr',
#  'frankweiss1731': '__swnsier137fka1',
#  'arielwinter': '__ewrrenilita',
#  'susanne_reiners': '__nenae_srsursein',
#  'bmwm': '__mwmb',
#  'guus.meeuwis': '__gwuuesue.mis',
#  'fashiongoalsz': '__nfoasgizoshla',
#  'artzincolor': '__trnarlzioco',
#  'ashleigh_jordan': '__agearhshdojnli_',
#  'nolangould': '__dlgulannoo',
#  'andrea_st14': '__1drtanes4a_',
#  'the.pinklemonade': '__teknoiehdel.nmap',
#  'artsfused': '__esadftrsu',
#  'igtattoogirls': '__gtorlsoiatgit',
#  'catrice.cosmetics': '__amcct.sisrticoece',
#  'gameofthrones': '__teromhnsegofa',
#  'yoga.tutorials': '__yrostiagoatul.',
#  'sombra': '__oambsr',
#  'pavlyukova.alina': '__avupa.avlklainoy',
#  'kjapa': '__aajkp',
#  'netflixing': '__nilexgfnit',
#  'brandpuntplus': '__rpbalsnpuudtn',
#  'casadicassa': '__asscdacsaia',
#  'loederloutje': '__rleoeeudltjo',
#  'florianwirsing': '__lgrrwiinoifnas',
#  'kendalljenner': '__andenrljlneek',
#  'lofy.nl': '__lynf.lo',
#  'arianagrande': '__ieraagannadr',
#  'yanart_drawing': '__n_aiwrdtnaragy',
#  'remibeer': '__breeemri',
#  'rihannals': '__nlhriansa',
#  'juliaverheyden': '__dhuejrliayvnee',
#  'ladygaga': '__agalgdya',
#  'mileycyrus': '__emsyirclyu',
#  'hollygshore': '__lhgoyslrhoe',
#  'ellehell': '__llhlleee',
#  'wendyvandijk3': '__kn3wvdanjydie',
#  '10e': '__01e',
#  'liliankropman': '__naaolnkrpliim',
#  'travel_2050': '__5vt0elr_0a2',
#  'how__to__draw': '____adtrwo_o_wh',
#  'selektta': '__eteaktsl',
#  'woahyoga': '__aoohwyag',
#  'justuszw': '__wzutjsus',
#  'heleenkoning': '__eehnioglenkn',
#  'thortful': '__ftlhotur',
#  'droetkerpizza_nl': '__ikzerpeztdor_lan',
#  'juliamekkes': '__kaeilkujsme',
#  'disneydrawstyle': '__lsnswyaytdriede',
#  'nuud.care': '__reduna.cu',
#  'watercolor': '__loaoewrrtc',
#  'gymtouches': '__ogeysmcuht',
#  'art.nights': '__ghts.tnira',
#  'sketchsecrets': '__hsscetesrteck',
#  'nathanhgshore': '__htrhnahgoeans',
#  'chiquitabanana': '__btnaniaiaahquc',
#  'rara_waarislara': '__sarlawraria_ara',
#  'rihanarihana_': '__nar_iarhhinaa',
#  'scottgshore': '__tsorcteoshg',
#  'snaptweet': '__tspweneat',
#  'maaster_lak': '__taeaklrsam_',
#  'radio538': '__oi5rd38a',
#  'glam_angel__': '___ggam_l_nlea',
#  'noah_eklu': '___hekoluan',
#  'johnnydemolofficial': '__deynmfnofcllhoiioja',
#  'pink_cheese_one': '__se_epknihee_ocn',
#  'dark_gloomy_art': '___mogdklyar_troa',
#  'artmotivators': '__aistomtarrtov',
#  'instagram': '__amirtgasn',
#  'mutemuse.official': '__f.iatemulsemoucif',
#  'jennifervandenberg_': '__ejdfea_vringenrennb',
#  'journe__': '__rjn_euo_',
#  'blakelively': '__kllaveleiyb',
#  'alisongredal': '__dileraoagnls',
#  'lnstababies': '__antssbealbi',
#  'universe.light.99': '__.gs9truviehn9le.i',
#  'maracimatoribus': '__csimaotuaarimbr',
#  'ifawnl': '__lwafin',
#  'mijnliefsteboek': '__entjksifebimloe',
#  'elsakahwaji': '__aaalhiwejks',
#  'sayf90': '__f09yas',
#  'musicfication': '__iinctisaofmcu',
#  'dopeblackart': '__tobdrcalpkea',
#  'niveanederland': '__dvealerendiann',
#  'z.biere': '__rzeie.b',
#  'vickypattison': '__icypaostitvnk',
#  'luzaa_b': '__bz_alau',
#  'alyno94': '__n4ylo9a',
#  'sarka_yoga': '__ka_yrogaas',
#  'aussiehairnl': '__aisihnlresau',
#  'nutsa_nanuashvili': '__uivnansualhtn_sai',
#  'waarutrechteet': '__rtuctehearawte',
#  'rustoleumnl': '__nmrutleolsu',
#  'your.boef': '__bouyfeo.r',
#  'lzwvocals': '__ovsalclzw',
#  'homeabs': '__ohbemsa',
#  'art.dunyaa': '__adny.artua',
#  'olaz_nederland': '__n_ldreazanoeld',
#  'happinez': '__zpiphnea',
#  'just.lifequotes': '__uiesttjo.useqlf',
#  'tutorialdegirl': '__rtdeagitliuolr',
#  'kn0wva': '__vknaw0',
#  'ingenieriainfinita': '__anigfitininaiernie',
#  'goedesier2015': '__o5desie10ge2r',
#  'jeroentjes': '__sreejjoetn',
#  'lilybris': '__llrbyisi',
#  'pinkmau___': '__mk_iapun__',
#  'franblam': '__laranmbf',
#  'vmbodocent': '__mvedooncbt',
#  'kruerdirndl3': '__deilknudrrr3',
#  'arts_promoter': '__aprme_rtotors',
#  'beyonce': '__yeoecnb',
#  'davinamichelleofficial': '__fcenlclfioahiaamiilved',
#  'lailasekarlangit': '__naarigeaslikaltl',
#  'wjanssen27': '__ns2aejws7n',
#  'taylorswift': '__wsayiotlrft',
#  'ratedmodernart': '__rtraoedenrtadm',
#  'sophiekasaei_': '__iaepokihe_ssa',
#  'kitharingtonig': '__hgiktniiratgno',
#  'hoagard': '__ahgaodr',
#  'marty_gshore': '__etrsrga_hmoy',
#  '_future.art': '__turfaue_rt.',
#  'peterdinklage': '__eelgikatrepnd',
#  'miraalou': '__maroaiul',
#  'illustrationow': '__wtiliuslrntooa',
#  'artbook.jpg': '__joar.pogbtk',
#  'lizekorpie': '__lprekoezii',
#  'koenroelink': '__keloenrikno',
#  'aaroncgshore': '__oncaosrerhag',
#  'starsgenesis': '__rtiasssnegse',
#  'leonardodicaprio': '__ncaaddopiroilroe',
#  'yuripomo': '__ryomiupo',
#  'sigridtennapel': '__inlgeadintersp',
#  'mahendrasinghsr': '__ragdisnrmehhnas',
#  'veg_drawings': '__girvswnag_ed',
#  'marijederoode': '__erraoojmedide',
#  'lambleystuart': '__aamlrbeulytst',
#  'lidlnederland': '__dedrlleidanln',
#  'mauskidss': '__siamkssud',
#  'cutesytee': '__etcteuyes',
#  'bloome_comics': '__cbeciomlmos_o',
#  'hitsomk': '__hoiskmt',
#  'damescinco': '__ismdeocanc',
#  'karlijntjeee7': '__tjljenira7eek',
#  'lynn_deputter': '__petteu_yrldnn',
#  'samincn': '__msncnai',
#  'kiezelstien': '__eenkliizste',
#  'kano.poser': '__aoks.epron',
#  'daanboom': '__banaoodm',
#  'modernartt': '__raodenttmr',
#  'gabrieledellotto': '__arotltleiobglede',
#  'a_portrait_': '__prao_i_ratt',
#  'humbertotan': '__attrnmubheo',
#  'gymalpha': '__lhaagmyp',
#  'arts_terra': '__r_tsaeartr',
#  'ems_050': '___s0em05',
#  'wiezewasjes': '__zwjesesiewa',
#  'marleenjacobs4': '__njaecra4boesml',
#  'giuliajrosa': '__uajioaglsir',
#  'sven_wientjes': '___iswestveejnn',
#  'kapil_1o_': '__1_oaklip_',
#  'hunkemoller': '__ouekemnhrll',
#  'straighthairwaves': '__reswsahahvitagrti',
#  'lilireinhart': '__ieaihrrinltl',
#  'anna.ol_ballet': '__a_ntabnla.olel',
#  'juliaoudewesselink': '__kaelwdneijiuosesul',
#  'crazyvoicess': '__szryovicecas',
#  'dyson1411': '__1s1yn4o1d',
#  'chantaljanzen.official': '__ltnneaazicafnfcaih.loj',
#  'universalpicturesnl': '__icrailuvpleresnsutn',
#  'erstwhile.brand': '__sn.rratledbiehw',
#  'hetpauperparadijs': '__peuetpidrahaprsja',
#  'diytraining': '__riinyndiatg',
#  'civicamsterdam': '__teicasmmcviard',
#  'aava_swim': '__asaimvaw_',
#  'pixelshe296': '__he6x2lp9esi',
#  'brita.nederland': '__.ndnadireeltbra',
#  'katha.linaa': '__.anhitkalaa',
#  'thisishappeningofficial': '__cstofihfinanielaspiigph',
#  'seysten': '__tsneyse',
#  'lupusdepoes': '__psuupdeesol',
#  'short_haircuts': '__srohuathtircs_',
#  '7usam86': '__sua78m6',
#  'channnnnnnd': '__annnnnhnndc',
#  'dannygraveland': '__ndnnvradeyagla',
#  'salonbnl': '__bnlnasol',
#  'damnvocals21': '__ncd1smaavlo2',
#  'sculptlifestyle': '__lslyceflttieusp',
#  'og3ne': '__n3goe',
#  'squatguide': '__guitduqase',
#  'method_nl': '__ndthmle_o',
#  'livianapoleon': '__oiinleolpaanv',
#  'nickschilder': '__iskcidhnlcer',
#  'kruerdirndl.com74': '__rrk4.iedu7monlcrd',
#  'arts.realism': '__lrrsase.amti',
#  'ad_nl': '__n_lad',
#  'florencewilmetjedansen': '__wfiorncseeneleemjtaldn',
#  'roodzwartinjehart': '__ndroarawtjtziehro',
#  '_reina_yamada_': '__yad_eam_ra_nia',
#  'being.memyselfandi': '__msifmnnyebe.eigdla',
#  'doutzen': '__znteoud',
#  'nico.rnz': '__rncoin.z',
#  'gymglobal': '__bgyolmgla',
#  'dennisweeningofficial': '__nfnowicgnidfeenieilas',
#  'cherrypie006': '__pryr6i0eche0',
#  'cinemien': '__neinimce',
#  'leekillust': '__ltlekislue',
#  'alexander.pechtold': '__eaocdal.nhtxeepldr',
#  'hasikomats': '__miokssahat',
#  'awwwfeed': '__wfawedew',
#  'wuvv.e': '__v.wveu',
#  'perfumesbyriri': '__bsmuirireyperf',
#  'linda': '__lanid',
#  'cjanzenfann': '__nznceaanfnj',
#  'mediumhairstyles': '__mlesrisudaeiymht',
#  'amazingglobepix': '__plagaogbiznxmie',
#  'the.ethical.hacker': '__.eckherhachtat.eil',
#  'asserroeiclub': '__ueraslcsrboie',
#  'lovricdean': '__iocelvdnra',
#  'vrlfit': '__fltvri',
#  'tumlhr': '__tlmhru',
#  'bol_com': '__bomlc_o',
#  'viralartz': '__arvirltza',
#  'arts.share.page': '__rsh..reaatepgsa',
#  'art_relates': '__serte_aralt',
#  'pup5779': '__7975upp',
#  'district_70': '__td0_7sictir',
#  'mitchleeuwe': '__htceelumwei',
#  'gemeenteamsterdam': '__eeeaeasnemrmdmttg',
#  'biodermal': '__mrodialeb',
#  'classicalcringe': '__sscccllrnieiaag',
#  '8fact': '__a8fct',
#  'sketch_dailydose': '__se_ohyaiddlskect',
#  'berryvanbeek2': '__kevnrbey2baer',
#  'curtainbangs': '__usnargbaticn',
#  'br1tth': '__brt1ht',
#  'carboneel_': '__ecerlnab_o',
#  'monicageuze': '__ceaugemzoni',
#  'gymposition': '__pgisnyootim',
#  'dierenasielamsterdamanimal2813': '__dma1mtsni2mlaeirsaaele3ai8nrde',
#  'zbynekkysela': '__bknlsezayyek',
#  'official_waylon_music': '__mlanoyf_i_uifsalwicco',
#  'milou_gr': '__mu_rgloi',
#  'claras.conscious.closet': '__in.c.eatcsauollcrososcs',
#  'homeabguide': '__edbugmoeaih',
#  'vid_vocals': '__dvcsilva_o',
#  'nakdfashion': '__inohakadfns',
#  'curtain.bangs': '__usarbcgnita.n',
#  'melissakerver': '__rsvmealksieer',
#  'arqui_locura': '__oala_uiqcurr',
#  'proficuriosi': '__cirioposrfiu',
#  'maradaamen': '__meadanaarm',
#  'itsmeekubra': '__irukemaebts',
#  'nicole.rutten1': '__.rcteiet1ounln',
#  'saatvik.kutta': '__uvaitaska.tkt',
#  'hm': '__hm',
#  'art.academy': '__crayaade.mt',
#  'worldxvoice': '__vcrxowdoeil',
#  'reebok': '__broeek',
#  'eccoshoes': '__scecosoeh',
#  'synapsemebaby': '__mespesbyanayb',
#  'vanstekkarl': '__tnrkeavalks',
#  'yewelinaspace': '__ieecsawnapley',
#  'howtopracticeyoga': '__pecgohirowatayotc',
#  'straighthair.babyy': '__rabsyhiagthratb.yi',
#  'kharim_amier': '__eraharmimik_',
#  'diversity.talks': '__t.aelrssividkty',
#  'cineart_nl': '__lcetianr_n',
#  'wotskiewoutofski': '__wiiktfoskowsoteu',
#  'npo3fm': '__ofnp3m',
#  'homnguyen': '__hngmoeuny',
#  'mattiemarieke': '__keimaatmirtee',
#  'yoga.addictgirl': '__dlaatciiogdyr.g',
#  'alfieeallen': '__enalialleef',
#  'brenthockley': '__becholretnyk',
#  'stijnvanvliet': '__eavvsnitnltji',
#  'fashions.tv': '__s.viotnhasf',
#  'stephaniepriscilla': '__slinalpecitrehaisp',
#  'annaboogaard': '__goranoabndaa',
#  '_khads._': '__sh__.kad',
#  'rumag': '__ragum',
#  'emilyy_fitness': '__sfyelmseniti_y',
#  'npo.nl': '__pn.nol',
#  'jeroenschutt': '__ecneuothjtsr',
#  'evakoreman': '__reeanamkvo',
#  'be.bloome': '__beb.eomol',
#  'zhuaan': '__anahuz',
#  'kgt_mfmfsti': '__tgitfkm_msf',
#  'raees_razz__': '__a__eszerazr_',
#  'selectdiyss': '__ieedtcsslsy',
#  'cheyenne_on_track': '__o_ynnenea_thcrkec',
#  'sigridfitness': '__fdgssesitinri',
#  'aixmalwtos': '__almoaitsxw',
#  'barbara.beurmanjer': '__ebabmrararju.beran',
#  'berberhumalda': '__lbdeubhaarmer',
#  'camera_duels': '__ealaurs_dmce',
#  'yogaalignment': '__eniaaotglnygm',
#  'the.essentials.amsterdam': '__etshnartsdm.elmtie.saaes',
#  'kicksnarebass': '__isskcakesarbn',
#  'dennizgoren': '__izenodnegnr',
#  'ilsedelangemusic': '__aeiesldglcmniues',
#  'mobigraph_er': '__mgrr_aoibhpe',
#  'vivazschoonhoven': '__ihavohnocvzneosv',
#  'thdrawing': '__andwthgri',
#  'theeconomist': '__iooentecstmh',
#  'instatructor': '__itrttacnosru',
#  'douwebob': '__odubeowb',
#  'bettenoortje': '__joentrbttoee',
#  'doorie78': '__e78iodor',
#  'space_girls_from_earth': '__l_riseemohpaf_gcsrart_',
#  'gymvascular': '__lcsruvygama',
#  'newyorkermag': '__yomgwarerekn',
#  'i_m_workout': '___kr_wouoitm',
#  'rosiesikkel': '__oeersksiilk',
#  'omfgvoice1': '__goo1vcmeif',
#  'sketch.instadaily': '__inlytadthscai.kse',
#  'kruidvat': '__iktdavur',
#  'agata1577': '__7ta75aa1g',
#  'jasperdemollin': '__mlsiedeanpoljr',
#  'de_volkskrant': '__avdeklr_noskt',
#  'britneyspears': '__ersbynrsitpae',
#  'anouk': '__oaukn',
#  'shanbei_0201': '__ns100_2hebai',
#  'zaful': '__azulf',
#  'natgeofineart': '__eigaenafnrott',
#  'gijoelle23': '__o32lgjeile',
#  'primevideonl': '__reiinodevplm',
#  'art_overnight': '__vahen_gorrtti',
#  'linstaphoto': '__ntatoisolhp',
#  'pleuniveen': '__enpieevnlu',
#  'straighthaircut': '__tirsahhgurttcai',
#  'haveaseat.nu': '__saetauenvha.',
#  'dreamsneverliechico': '__vmndiccsrehioerelae',
#  'samhairwolfryder': '__ylarresorifdhamw',
#  'marnix.ackermans': '__eiasxrcknarmamn.',
#  'jesseklaver': '__seeveslarkj',
#  'straighthairwavers': '__gihhrstrsriawaveat',
#  'agathesorlet': '__reahtoetagls',
#  'mrmarvis': '__ammrrvis',
#  'sander_van_rijn': '__ajrrns__vnadine',
#  'elisevaneijk': '__ljenseeiakvi',
#  'visa_nederland': '__vesedrlindna_a',
#  'son.of.joyce': '__cfoesnyoj.o.',
#  'alwerart': '__lterrwaa',
#  'pencil_arts_group': '__p_rocsutpar_ingel',
#  'theavanderparre': '__epaenhreartrdav',
#  'thegalaxylovesu': '__vyexeslulahagot',
#  'omgvoices': '__ogecivmso',
#  'girlyexercises': '__sgyilxrciseeer',
#  'chloegshore1': '__oehslrhe1gco',
#  'eyesneverliechico': '__loeevrhcieeceynsi',
#  'babemometv': '__membeoatvb',
#  'mondkapjesmovement': '__nskejntdmveeamopmo',
#  'kimkardashian': '__mkiadsairanhk',
#  'artcraftsy': '__rrstayfact',
#  'lola.burke_': '__klura._beol',
#  'buzzfeedtasty': '__bzytedzstafeu',
#  'arts_moonlight': '__nrtmo_lgshiota',
#  'saskia.brouwer': '__.baosusaiwrkre',
#  'unclewol': '__cleonwul',
#  'zacefron': '__efnocraz',
#  'tattoo.kobenski': '__aoteoktntso.kbi',
#  'yoga.goodvibes': '__ovo.beogdiyasg',
#  'noordriessen': '__ndisosrerneo',
#  'sara.brust': '__rsubsr.taa',
#  '_crazy_anyone_o': '__yzn_y_nc_oaeoar',
#  'justinbieber': '__ubebejisirnt',
#  'tijmenkappen': '__etjkeinpanmp',
#  'felinedewit': '__eiewidtfenl',
#  'arts2love': '__sl2torave',
#  'saarts_': '__atss_ra',
#  'art_dailydose': '__saityaold_rde',
#  'fillingpieces': '__elsiegfiipnlc',
#  'omconnection': '__noeimoonctcn',
#  'fankling_elliot': '__lfeokgi_inlntal',
#  'galbani_nederland': '__lnediaerndganal_b',
#  'susies35mm': '__m5eumsis3s',
#  'quincykrijger': '__nrcgujyekqiri',
#  'purpleheartcraft': '__eaaulcrppfhrtert',
#  'mitchelkoppers': '__tcrseppomiklhe',
#  'bearbrickjia': '__brrjieicakab',
#  'selenagomez': '__soangzemeel',
#  'geartsjemb': '__aegtrsebmj',
#  'ania_75': '__n_aai57',
#  'judithvrolijk': '__jdijohkvriult',
#  'liessmits': '__esltmissi',
#  'arts.mrv': '__tmrsa.vr',
#  'ten_grande': '__r_gadneetn',
#  'yogavered': '__egaoyevrd',
#  'my.art.tutorials': '__..tmriytlaoatrus',
#  'kimfrench87': '__crfk8hine7m',
#  'hannahbarrettyoga': '__gnoraehraanhbaytt',
#  'wonderful.world.pic': '__oiruwp.wrc.olledfdn',
#  'timsenders': '__emntsrides',
#  'sivan.ka': '__na.vksai',
#  'hiiamgorilla': '__ialaihmoirgl',
#  'vocalupload': '__lulvaaocdpo',
#  'sebwabo': '__obasebw',
#  '_hmerologio_': '__groomeo_l_ih',
#  'fitmoral': '__fmtlrioa',
#  'thisishappeningamsterdam': '__aptserhehnnamsiadmispitg',
#  'samomoods': '__odssmoamo',
#  'worry__lines': '__oli__ywrrnse',
#  'globaltalents': '__gbeaatnstloll',
#  'nooniedraws': '__weainonsdor',
#  'above.art.ru': '__.abr.euravot',
#  'helena0sofia': '__aaiefehsln0o',
#  'albertheijn': '__ijnablrtehe',
#  'rosefield': '__edrieofsl',
#  'artstrending': '__etitnsgdrarn',
#  'lovebeautyandplanet_nl': '__bnelpnyelnteatvloda_ua',
#  'nicolettekluijver_': '__itklconirtjuvel_ee',
#  'thedoodledesk': '__eteddkhledoos',
#  'worldfoodprogramme': '__wmprdlmoerodafgroo',
#  'adele': '__adlee',
#  'princes_nl': '___srcnienlp',
#  'ying_fll': '__lyi_gfln',
#  'workoutcode': '__redwoouoktc',
#  'gostarer.com66': '__eatg6rroosm6c.',
#  'bison_nl': '___insnlbo',
#  'pauletteceyrat': '__pteeruytlactea',
#  'saraheltounsiofficial': '__nefiootalalarishfiscu',
#  'ddlovato': '__tdoovadl',
#  'yogadailypractice': '__lcidteaygicroapya',
#  'jadorevintage': '__ednjevgioaart',
#  'flexibilitytraining': '__enxrfyliibtiiiatgln',
#  'vibetutoriais': '__voisubaittier',
#  'yaeltuasela': '__taaeleayuls',
#  'alecmaas': '__lasacame',
#  'artdaily_viral': '__larayt_vraidli',
#  'nly_for_crush': '__nfs_r_lhrocyu',
#  'simonkeizer': '__rnzomksiiee',
#  'simo.ouzalii': '__siooamziil.u',
#  'bodineschotsman': '__tmeonashdconbis',
#  'evanorah': '__voarhena',
#  'jelkavanhouten': '__tvlajonkaheeun',
#  'dove6803': '__v0o38ed6',
#  'gaby.blaaser': '__ysa.arblbgae',
#  'worldofmusic': '__owrfodcusmli',
#  'pleunbierbooms': '__eueisrnopobmbl',
#  'inspirerendleven': '__dnnsenprreielive',
#  'annanooshin': '__ohnsaianonn',
#  'borisbrussel': '__sorrsbbieslu',
#  'nhnieuws': '__usnhienw',
#  'iciparisxlnl': '__iprxsinaillc',
#  'muhammedsalah_': '__mhlmuaha_eamsd',
#  'zwitsalnederland': '__edrlzaaeidlnstwn',
#  'stvluchteling': '__cthevignlulst',
#  'skinnypt': '__nisykntp',
#  'fitmethods': '__ttfhedomis',
#  'gemwhelan': '__mnhaelweg',
#  'nachtvdvluchteling': '__tinlngvduvhchctlea',
#  'blackworknow': '__aowwcnkbrokl',
#  'shooky_dough': '__kdo_ohgusyho',
#  'iamfeelingmyself': '__mlyneieslmegfifa',
#  'itslaiafidalgo': '__afgiaaidtiolls',
#  'poptradingcompany': '__piacgyptrdonopamn',
#  'r.a.a.k.t': '__r..a..atk',
#  'aurorabowkett': '__botaeoturarkw',
#  'sjoemeliers': '__rmioeljsese',
#  'real_vocals_': '__ralo_esc_val',
#  'nathalieemmanuel': '__hnuemnmetlaaeali',
#  'mayambili': '__iablmmiay',
#  '22.79am': '__2m7.a92',
#  'gverbaan': '__gavnebar',
#  'maroua93': '__uoam39ra',
#  'stormdennis': '__insdrsotmne',
#  'ministerievanveiligheiden': '__siraedhievmeitienennilvgi',
#  'singingshiz': '__gnnsgiizhis',
#  'flxmitnacht': '__chtalnmftxi',
#  'jeffreykoole': '__keejeofloyfr',
#  'dreamsportsnl': '__nmrprsdestola',
#  'omroepbnnvara': '__naornvmpbraeo',
#  'enews': '__wsene',
#  'bebeautymood': '__boabdtueeoym',
#  'cityshapesnl': '__isalhcyentps',
#  'hagecharlotte': '__aralottheehgc',
#  'baderquamar': '__aaudrermqba',
#  'marns': '__sarnm',
#  'lily11277': '__ll17y172i',
#  'etsmanofficial': '__isfcmaonlfeita',
#  'artesdepressao': '__srodaetaseersp',
#  'anastasiakarachristou': '__ichaissstautkrnaaraoa',
#  'fitfemalesclub': '__fflulsciabtmee',
#  'melena9791': '__l7n9e19ame',
#  'weledabenelux': '__eweuxnlbadlee',
#  'lustellie': '__tlieleuls',
#  'zwokbor': '__koobwrz',
#  'donjavdl': '__djnvlaod',
#  'gymmonkey_nl': '__neo_mlygkynm',
#  'cobyvanbeeren': '__onbaebeecvryn',
#  'alexandernl': '__eennrllaadx',
#  'ronald.vanrijn.3': '__rd3i.annjlron.va',
#  'yucn.li': '__l.ncyiu',
#  'stevie_bear': '__vbeetria_se',
#  'duaaart_': '__dtaaa_ur',
#  'cindyfrench04': '__echfrcdnni4y0',
#  'spuitenenslikken': '__nseiukilpetenskn',
#  'peterpannekoek': '__pnneeekokeptar',
#  'sweetcatsgo': '__staceotsweg',
#  'pastinaakt': '__tipansatka',
#  'organicbasics': '__socsiarngciba',
#  'fubiz': '__zufib',
#  'phalerieau': '__aurpaleeih',
#  'gymshark': '__samgrhky',
#  'globalcreatived': '__gceabloidvtrela',
#  'verwijderrnep': '__reeirvdrwenjp',
#  'ikonicfitness': '__ssnoniteickif',
#  'bregjeschreuders': '__hseuesbercjrrgde',
#  'renevnleeuwen': '__ulweneerenenv',
#  'rab._.an': '___a..rban',
#  'luukluukluukhoi': '__iuulkolukhkuulu',
#  '_globalart_': '__olrta__albg',
#  'jancornelisblokhuis': '__njoaebkuriilsclohns',
#  'eyedrawing': '__eawgndeiyr',
#  'dejeugd': '__djegedu',
#  'art.ig': '__a.tigr',
#  'portrait_viral': '__iattroriapvr_l',
#  'bella.ruis': '__.ilrseluab',
#  'abs_at_home': '__oa_st_eamhb'}

# %% [markdown]
# #### Find other sensitive info

# %% [markdown]
# Extract name of user

# %%
def names():
    
    # Load profile.json to get name of user
    with open(json_file_account, encoding = "utf8") as json_user:
        name = json.load(json_user)

    # Find replacement for user's username 
    with open(json_file_user, encoding = "utf8") as json_user:
        user = json.load(json_user)
    
    user = pd.DataFrame.from_dict(user, 
        orient = 'index').T 
    
    # Create dictionary
    name_dic = {}
    name_dic = {name['registration_info']['registration_username']: usernames[user['username'][0]]}

    return(name_dic)

names()
# Out:
# {'Roos': '__ovrsrooo'}

# %% [markdown]
# Extract mail of user

# %%
def mail():
    
    # Load profile.json to get username of user
    with open(json_file_user, encoding = "utf8") as json_user:
        user = json.load(json_user)
    
    # Create dictionary
    mail_dic = {}
    mail_dic = {user['email']: usernames[user['username']]}
    
    return(mail_dic)

mail()
# Out:
# {'vladimirvladimirina@gmail.com': '__ovrsrooo'}

# %% [markdown]
# ### 5.Create function to search for sensitive info and replace it with pseudo data

# %% [markdown]
# #### Save dictionary to key file

# %%
# Combine all usernames with the name and mail of the user
df = pd.DataFrame(list(usernames.items()))
df = df.append(list(mail().items()), ignore_index=True)
df = df.append(list(names().items()), ignore_index=True)

df = df.rename(columns={0: 'id', 1: 'subt'})
df
# Out:
#                                 id                subt
# 0                         roosvoor          __ovrsrooo
# 1                         beberson          __obrbnsee
# 2                 danielpolosetzky  __oolptadlnyiezesk
# 3                      sophie_soof       __ohiso_ofspe
# 4                          symonab           __asmonyb
# ..                             ...                 ...
# 831                 portrait_viral    __iattroriapvr_l
# 832                     bella.ruis        __.ilrseluab
# 833                    abs_at_home       __oa_st_eamhb
# 834  vladimirvladimirina@gmail.com          __ovrsrooo
# 835                           Roos          __ovrsrooo
#
# [836 rows x 2 columns]

# %%
# Write the sensitive info with corresponding substitutes to csv
df.to_csv('keys.csv', index = False, encoding='utf-8')

# %% [markdown]
# #### Find and replace usernames in all files

# %%
# Look for all usernames in the instagram folder and replace it with substitutes
from anonymize import Anonymize

anonymize_csv = Anonymize('keys.csv')
anonymize_csv.substitute(data, 'anonymized_'+usernames[username])

print('Your instagram data has been succesfully anonymized!')
print('The data is saved in the following folder: anonymized'+usernames[username])
# Out:
# Your instagram data has been succesfully anonymized!
# The data is saved in the following folder: anonymized__ovrsrooo

# %% [markdown]
# Please send this folder to researcher X via method B. Thank you!
